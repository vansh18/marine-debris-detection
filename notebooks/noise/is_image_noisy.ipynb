# %%
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt

#  Extract a Noise Metric

# image_path_1 = r'C:\Users\ASUS\OneDrive\Desktop\marine-debris-detection\data\original_data\images\vid_000433_frame0000005.jpg'
# image_path_2 = r'C:\Users\ASUS\OneDrive\Desktop\marine-debris-detection\data\original_data\images\vid_000003_frame0000001.jpg'

# def calculate_sharpness(image_path):
#     image = cv2.imread(image_path)
#     gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#     return cv2.Laplacian(gray, cv2.CV_64F).var()

# sharpness_1 = calculate_sharpness(image_path_1)
# sharpness_2 = calculate_sharpness(image_path_2)

# print(f"Sharpness of image 1: {sharpness_1}")
# print(f"Sharpness of image 2: {sharpness_2}")

# # Display the images 
# image_1 = cv2.imread(image_path_1)
# image_2 = cv2.imread(image_path_2)

# plt.figure(figsize=(10, 10))
# plt.subplot(1, 2, 1)
# plt.imshow(cv2.cvtColor(image_1, cv2.COLOR_BGR2RGB))
# plt.title(f"Sharpness: {sharpness_1}")
# plt.axis('off')

# plt.subplot(1, 2, 2)
# plt.imshow(cv2.cvtColor(image_2, cv2.COLOR_BGR2RGB))
# plt.title(f"Sharpness: {sharpness_2}")
# plt.axis('off')

# plt.show()

# %%
import cv2

# Define your sharpness calculation function
def calculate_sharpness(image_path):
    """
    Calculate the sharpness of an image using the variance of the Laplacian.
    
    Args:
        image_path (str): Path to the image file.
    
    Returns:
        float: Sharpness value (higher values indicate sharper images).
    """
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if image is None:
        print(f"Failed to load image: {image_path}")
        return None
    laplacian = cv2.Laplacian(image, cv2.CV_64F)
    sharpness = laplacian.var()
    return sharpness

# Path to the sampled images text file
sampled_images_file = "sampled_images.txt"

# Read the sampled image paths from the text file
with open(sampled_images_file, 'r') as file:
    sampled_image_paths = file.read().splitlines()

# Calculate sharpness for each image
sharpness_results = []
for image_path in sampled_image_paths:
    sharpness = calculate_sharpness(image_path)
    if sharpness is not None:
        sharpness_results.append((image_path, sharpness))
        print(f"Image: {image_path}, Sharpness: {sharpness}")

# Optional: Save the sharpness results to a CSV file
import csv

output_csv = "sharpness_results.csv"
with open(output_csv, 'w', newline='') as csvfile:
    csvwriter = csv.writer(csvfile)
    csvwriter.writerow(["Image Path", "Sharpness"])
    csvwriter.writerows(sharpness_results)

print(f"Sharpness results saved to {output_csv}")
# Out:
# Image: ../data/original_data/images\vid_000142_frame0000004.jpg, Sharpness: 2633.5844280671295
# Image: ../data/original_data/images\vid_000125_frame0000021.jpg, Sharpness: 3113.8220618183577
# Image: ../data/original_data/images\vid_000158_frame0000124.jpg, Sharpness: 1146.528340963411
# Image: ../data/original_data/images\vid_000132_frame0000041.jpg, Sharpness: 3345.3977004729068
# Image: ../data/original_data/images\vid_000288_frame0000044.jpg, Sharpness: 362.58486761496374
# Image: ../data/original_data/images\vid_000273_frame0000012.jpg, Sharpness: 1005.1563107611763
# Image: ../data/original_data/images\vid_000340_frame0000021.jpg, Sharpness: 3612.176557167293
# Image: ../data/original_data/images\vid_000297_frame0000011.jpg, Sharpness: 154.78030181538145
# Image: ../data/original_data/images\vid_000282_frame0000051.jpg, Sharpness: 366.67675555073305
# Image: ../data/original_data/images\vid_000331_frame0000259.jpg, Sharpness: 2946.7059464999143
# Image: ../data/original_data/images\vid_000361_frame0000037.jpg, Sharpness: 3149.760943392716
# Image: ../data/original_data/images\vid_000162_frame0000037.jpg, Sharpness: 1701.8133019803934
# Image: ../data/original_data/images\vid_000031_frame0000043.jpg, Sharpness: 3232.8966345092563
# Image: ../data/original_data/images\vid_000116_frame0000034.jpg, Sharpness: 3139.563049082589
# Image: ../data/original_data/images\vid_000022_frame0000040.jpg, Sharpness: 2905.6192319029474
# Image: ../data/original_data/images\vid_000255_frame0000096.jpg, Sharpness: 928.0794503085077
# Image: ../data/original_data/images\vid_000145_frame0000031.jpg, Sharpness: 2972.2540326902704
# Image: ../data/original_data/images\vid_000350_frame0000018.jpg, Sharpness: 2828.9290837571807
# Image: ../data/original_data/images\vid_000155_frame0000054.jpg, Sharpness: 2925.17429442706
# Image: ../data/original_data/images\vid_000111_frame0000009.jpg, Sharpness: 1789.799766050752
# Image: ../data/original_data/images\vid_000316_frame0000015.jpg, Sharpness: 664.7934470802253
# Image: ../data/original_data/images\vid_000109_frame0000024.jpg, Sharpness: 1729.854914882197
# Image: ../data/original_data/images\vid_000106_frame0000033.jpg, Sharpness: 1240.3646433657714
# Image: ../data/original_data/images\vid_000086_frame0000025.jpg, Sharpness: 2884.409189021717
# Image: ../data/original_data/images\vid_000289_frame0000029.jpg, Sharpness: 378.343256871805
# Image: ../data/original_data/images\vid_000285_frame0000136.jpg, Sharpness: 427.06542605288575
# Image: ../data/original_data/images\vid_000332_frame0000087.jpg, Sharpness: 3150.2679035148512
# Image: ../data/original_data/images\vid_000331_frame0000286.jpg, Sharpness: 3205.9903043537925
# Image: ../data/original_data/images\vid_000282_frame0000054.jpg, Sharpness: 450.31569290069865
# Image: ../data/original_data/images\vid_000295_frame0000023.jpg, Sharpness: 396.40482973237636
# Image: ../data/original_data/images\vid_000054_frame0000003.jpg, Sharpness: 3627.4514526248267
# Image: ../data/original_data/images\vid_000048_frame0000018.jpg, Sharpness: 3128.8732609546473
# Image: ../data/original_data/images\vid_000077_frame0000014.jpg, Sharpness: 2768.3196837274713
# Image: ../data/original_data/images\vid_000048_frame0000001.jpg, Sharpness: 3047.6494798010976
# Image: ../data/original_data/images\vid_000437_frame0000051.jpg, Sharpness: 1894.6768719516242
# Image: ../data/original_data/images\vid_000297_frame0000013.jpg, Sharpness: 158.12491795213907
# Image: ../data/original_data/images\vid_000086_frame0000019.jpg, Sharpness: 2896.2421827474254
# Image: ../data/original_data/images\vid_000005_frame0000011.jpg, Sharpness: 2760.196086576872
# Image: ../data/original_data/images\vid_000047_frame0000024.jpg, Sharpness: 3025.9462918378963
# Image: ../data/original_data/images\vid_000116_frame0000028.jpg, Sharpness: 2904.6528524403197
# Image: ../data/original_data/images\vid_000202_frame0000019.jpg, Sharpness: 792.4995283130787
# Image: ../data/original_data/images\vid_000123_frame0000029.jpg, Sharpness: 3233.034617851699
# Image: ../data/original_data/images\vid_000082_frame0000010.jpg, Sharpness: 3209.308140258488
# Image: ../data/original_data/images\vid_000547_frame0000019.jpg, Sharpness: 2621.60620356653
# Image: ../data/original_data/images\vid_000285_frame0000056.jpg, Sharpness: 423.01169618025415
# Image: ../data/original_data/images\vid_000364_frame0000014.jpg, Sharpness: 2862.500892718097
# Image: ../data/original_data/images\vid_000035_frame0000084.jpg, Sharpness: 3120.9096455603544
# Image: ../data/original_data/images\vid_000293_frame0000009.jpg, Sharpness: 1687.2693427692848
# Image: ../data/original_data/images\vid_000283_frame0000030.jpg, Sharpness: 343.6290053819444
# Image: ../data/original_data/images\vid_000278_frame0000005.jpg, Sharpness: 1610.8158532530651
# Image: ../data/original_data/images\vid_000077_frame0000025.jpg, Sharpness: 2616.8535701254937
# Image: ../data/original_data/images\vid_000035_frame0000087.jpg, Sharpness: 3292.1390238525355
# Image: ../data/original_data/images\vid_000331_frame0000175.jpg, Sharpness: 2967.1722798332476
# Image: ../data/original_data/images\vid_000028_frame0000006.jpg, Sharpness: 2530.6000874480233
# Image: ../data/original_data/images\vid_000306_frame0000004.jpg, Sharpness: 844.152956150301
# Image: ../data/original_data/images\vid_000368_frame0000082.jpg, Sharpness: 2855.918558067498
# Image: ../data/original_data/images\vid_000110_frame0000013.jpg, Sharpness: 1964.9347659331063
# Image: ../data/original_data/images\vid_000291_frame0000064.jpg, Sharpness: 755.6484513212396
# Image: ../data/original_data/images\vid_000158_frame0000001.jpg, Sharpness: 1387.2899653777408
# Image: ../data/original_data/images\vid_000079_frame0000013.jpg, Sharpness: 3093.8440326216823
# Image: ../data/original_data/images\vid_000050_frame0000020.jpg, Sharpness: 3240.855784259259
# Image: ../data/original_data/images\vid_000346_frame0000026.jpg, Sharpness: 2900.859097712275
# Image: ../data/original_data/images\vid_000081_frame0000030.jpg, Sharpness: 2725.941974422666
# Image: ../data/original_data/images\vid_000154_frame0000009.jpg, Sharpness: 396.00806467412417
# Image: ../data/original_data/images\vid_000052_frame0000064.jpg, Sharpness: 3492.9331425351984
# Image: ../data/original_data/images\vid_000152_frame0000007.jpg, Sharpness: 1049.320449054784
# Image: ../data/original_data/images\vid_000212_frame0000007.jpg, Sharpness: 350.7479255601838
# Image: ../data/original_data/images\vid_000140_frame0000020.jpg, Sharpness: 2778.176653363567
# Image: ../data/original_data/images\vid_000021_frame0000029.jpg, Sharpness: 2822.1915505998995
# Image: ../data/original_data/images\vid_000275_frame0000006.jpg, Sharpness: 1586.1648246708623
# Image: ../data/original_data/images\vid_000074_frame0000020.jpg, Sharpness: 4202.116133165616
# Image: ../data/original_data/images\vid_000075_frame0000057.jpg, Sharpness: 2707.0791807041014
# Image: ../data/original_data/images\vid_000045_frame0000039.jpg, Sharpness: 2847.421103535033
# Image: ../data/original_data/images\vid_000319_frame0000029.jpg, Sharpness: 3083.130600594183
# Image: ../data/original_data/images\vid_000143_frame0000028.jpg, Sharpness: 3003.235826849708
# Image: ../data/original_data/images\vid_000171_frame0000012.jpg, Sharpness: 1252.975404543896
# Image: ../data/original_data/images\vid_000054_frame0000018.jpg, Sharpness: 3408.3969479764423
# Image: ../data/original_data/images\vid_000132_frame0000059.jpg, Sharpness: 2816.521295995275
# Image: ../data/original_data/images\vid_000269_frame0000032.jpg, Sharpness: 996.022051375493
# Image: ../data/original_data/images\vid_000291_frame0000019.jpg, Sharpness: 281.19320293849535
# Image: ../data/original_data/images\vid_000288_frame0000067.jpg, Sharpness: 367.9070088225188
# Image: ../data/original_data/images\vid_000104_frame0000022.jpg, Sharpness: 2636.1757993996243
# Image: ../data/original_data/images\vid_000435_frame0000028.jpg, Sharpness: 313.5383534697774
# Image: ../data/original_data/images\vid_000132_frame0000099.jpg, Sharpness: 2910.023200376991
# Image: ../data/original_data/images\vid_000235_frame0000149.jpg, Sharpness: 367.5202851589292
# Image: ../data/original_data/images\vid_000142_frame0000027.jpg, Sharpness: 2460.389775711591
# Image: ../data/original_data/images\vid_000151_frame0000006.jpg, Sharpness: 857.4828168327425
# Image: ../data/original_data/images\vid_000340_frame0000034.jpg, Sharpness: 3653.8197847221627
# Image: ../data/original_data/images\vid_000158_frame0000087.jpg, Sharpness: 1226.538714059404
# Image: ../data/original_data/images\vid_000114_frame0000037.jpg, Sharpness: 3372.945403377678
# Image: ../data/original_data/images\vid_000150_frame0000029.jpg, Sharpness: 1057.3281072851028
# Image: ../data/original_data/images\vid_000282_frame0000061.jpg, Sharpness: 458.9164010239505
# Image: ../data/original_data/images\vid_000255_frame0000014.jpg, Sharpness: 865.7797787903754
# Image: ../data/original_data/images\vid_000282_frame0000024.jpg, Sharpness: 323.8889554718311
# Image: ../data/original_data/images\vid_000551_frame0000111.jpg, Sharpness: 2687.6197422258415
# Image: ../data/original_data/images\vid_000121_frame0000008.jpg, Sharpness: 3372.1212617154747
# Image: ../data/original_data/images\vid_000148_frame0000024.jpg, Sharpness: 405.68661645876193
# Image: ../data/original_data/images\vid_000081_frame0000037.jpg, Sharpness: 2538.5223594497793
# Image: ../data/original_data/images\vid_000317_frame0000024.jpg, Sharpness: 633.8044798417874
# Image: ../data/original_data/images\vid_000080_frame0000089.jpg, Sharpness: 2771.460578028311
# Image: ../data/original_data/images\vid_000291_frame0000059.jpg, Sharpness: 630.0316574360411
# Image: ../data/original_data/images\vid_000271_frame0000043.jpg, Sharpness: 751.5779860809702
# Image: ../data/original_data/images\vid_000438_frame0000003.jpg, Sharpness: 1900.0305089999142
# Image: ../data/original_data/images\vid_000108_frame0000012.jpg, Sharpness: 1183.835133011798
# Image: ../data/original_data/images\vid_000532_frame0000200.jpg, Sharpness: 2911.524306603414
# Image: ../data/original_data/images\vid_000156_frame0000016.jpg, Sharpness: 1611.4317185175662
# Image: ../data/original_data/images\vid_000152_frame0000012.jpg, Sharpness: 1046.9773466796541
# Image: ../data/original_data/images\vid_000161_frame0000012.jpg, Sharpness: 1500.2495394418124
# Image: ../data/original_data/images\vid_000332_frame0000088.jpg, Sharpness: 3046.744815174659
# Image: ../data/original_data/images\vid_000114_frame0000030.jpg, Sharpness: 2874.406774113845
# Image: ../data/original_data/images\vid_000152_frame0000027.jpg, Sharpness: 630.1111567081069
# Image: ../data/original_data/images\vid_000440_frame0000079.jpg, Sharpness: 4465.697008421866
# Image: ../data/original_data/images\vid_000052_frame0000072.jpg, Sharpness: 3760.084942064793
# Image: ../data/original_data/images\vid_000082_frame0000014.jpg, Sharpness: 3185.2230303831357
# Image: ../data/original_data/images\vid_000075_frame0000100.jpg, Sharpness: 2883.0097475420575
# Image: ../data/original_data/images\vid_000144_frame0000005.jpg, Sharpness: 2265.1857801253973
# Image: ../data/original_data/images\vid_000155_frame0000029.jpg, Sharpness: 3249.6492709038257
# Image: ../data/original_data/images\vid_000255_frame0000024.jpg, Sharpness: 826.4044420008947
# Image: ../data/original_data/images\vid_000268_frame0000003.jpg, Sharpness: 824.8780558060259
# Image: ../data/original_data/images\vid_000081_frame0000022.jpg, Sharpness: 2693.687270650196
# Image: ../data/original_data/images\vid_000072_frame0000004.jpg, Sharpness: 2394.842347835695
# Image: ../data/original_data/images\vid_000269_frame0000018.jpg, Sharpness: 871.7751249516407
# Image: ../data/original_data/images\vid_000036_frame0000045.jpg, Sharpness: 3020.6803484215443
# Image: ../data/original_data/images\vid_000260_frame0000066.jpg, Sharpness: 1749.025857701548
# Image: ../data/original_data/images\vid_000152_frame0000008.jpg, Sharpness: 1060.8801711017543
# Image: ../data/original_data/images\vid_000145_frame0000081.jpg, Sharpness: 2375.6253383672815
# Image: ../data/original_data/images\vid_000259_frame0000009.jpg, Sharpness: 913.9399290950989
# Image: ../data/original_data/images\vid_000085_frame0000027.jpg, Sharpness: 2670.3457631458023
# Image: ../data/original_data/images\vid_000132_frame0000028.jpg, Sharpness: 2825.5328202155138
# Image: ../data/original_data/images\vid_000084_frame0000071.jpg, Sharpness: 2718.1673550144797
# Image: ../data/original_data/images\vid_000045_frame0000063.jpg, Sharpness: 2934.5379646583506
# Image: ../data/original_data/images\vid_000316_frame0000011.jpg, Sharpness: 507.8588906973045
# Image: ../data/original_data/images\vid_000063_frame0000026.jpg, Sharpness: 3083.6017912427596
# Image: ../data/original_data/images\vid_000432_frame0000013.jpg, Sharpness: 398.5890816306785
# Image: ../data/original_data/images\vid_000127_frame0000008.jpg, Sharpness: 2380.892658478128
# Image: ../data/original_data/images\vid_000154_frame0000007.jpg, Sharpness: 404.01367213457945
# Image: ../data/original_data/images\vid_000429_frame0000010.jpg, Sharpness: 361.8028628423997
# Image: ../data/original_data/images\vid_000108_frame0000034.jpg, Sharpness: 1281.5221172107754
# Image: ../data/original_data/images\vid_000431_frame0000017.jpg, Sharpness: 236.93042793367277
# Image: ../data/original_data/images\vid_000151_frame0000029.jpg, Sharpness: 676.2720278258691
# Image: ../data/original_data/images\vid_000020_frame0000002.jpg, Sharpness: 3151.2025777343742
# Image: ../data/original_data/images\vid_000275_frame0000001.jpg, Sharpness: 1638.6731587571803
# Image: ../data/original_data/images\vid_000148_frame0000064.jpg, Sharpness: 439.98033333212777
# Image: ../data/original_data/images\vid_000210_frame0000058.jpg, Sharpness: 883.4435444369093
# Image: ../data/original_data/images\vid_000138_frame0000015.jpg, Sharpness: 1860.9958383163773
# Image: ../data/original_data/images\vid_000551_frame0000065.jpg, Sharpness: 2552.02485422805
# Image: ../data/original_data/images\vid_000080_frame0000077.jpg, Sharpness: 2659.00304627004
# Image: ../data/original_data/images\vid_000086_frame0000047.jpg, Sharpness: 2921.3695695082088
# Image: ../data/original_data/images\vid_000251_frame0000034.jpg, Sharpness: 1978.9050397612307
# Image: ../data/original_data/images\vid_000002_frame0000013.jpg, Sharpness: 2595.7724034519792
# Image: ../data/original_data/images\vid_000112_frame0000058.jpg, Sharpness: 617.5797429964795
# Image: ../data/original_data/images\vid_000431_frame0000045.jpg, Sharpness: 302.40414914266114
# Image: ../data/original_data/images\vid_000143_frame0000073.jpg, Sharpness: 3179.5039194937426
# Image: ../data/original_data/images\vid_000443_frame0000084.jpg, Sharpness: 1246.1540046248072
# Image: ../data/original_data/images\vid_000072_frame0000028.jpg, Sharpness: 2258.2277843101633
# Image: ../data/original_data/images\vid_000094_frame0000039.jpg, Sharpness: 4121.996177869168
# Image: ../data/original_data/images\vid_000142_frame0000104.jpg, Sharpness: 2620.572540804505
# Image: ../data/original_data/images\vid_000269_frame0000023.jpg, Sharpness: 1011.3515663836108
# Image: ../data/original_data/images\vid_000370_frame0000058.jpg, Sharpness: 2657.6376316609867
# Image: ../data/original_data/images\vid_000433_frame0000007.jpg, Sharpness: 196.00536592878595
# Image: ../data/original_data/images\vid_000255_frame0000055.jpg, Sharpness: 957.6464012324244
# Image: ../data/original_data/images\vid_000108_frame0000005.jpg, Sharpness: 1165.0918562623242
# Image: ../data/original_data/images\vid_000282_frame0000021.jpg, Sharpness: 316.89937714120373
# Image: ../data/original_data/images\vid_000547_frame0000012.jpg, Sharpness: 2711.633657640258
# Image: ../data/original_data/images\vid_000288_frame0000051.jpg, Sharpness: 374.0635504543896
# Image: ../data/original_data/images\vid_000319_frame0000028.jpg, Sharpness: 3294.68566563405
# Image: ../data/original_data/images\vid_000039_frame0000012.jpg, Sharpness: 2667.4931604289914
# Image: ../data/original_data/images\vid_000272_frame0000019.jpg, Sharpness: 681.4193088442202
# Image: ../data/original_data/images\vid_000048_frame0000010.jpg, Sharpness: 3110.271730105929
# Image: ../data/original_data/images\vid_000270_frame0000041.jpg, Sharpness: 934.3164935366028
# Image: ../data/original_data/images\vid_000049_frame0000012.jpg, Sharpness: 3322.4239338729208
# Image: ../data/original_data/images\vid_000041_frame0000022.jpg, Sharpness: 2768.737836740719
# Image: ../data/original_data/images\vid_000024_frame0000033.jpg, Sharpness: 2661.31693312662
# Image: ../data/original_data/images\vid_000028_frame0000039.jpg, Sharpness: 2538.7623765431504
# Image: ../data/original_data/images\vid_000112_frame0000048.jpg, Sharpness: 380.97050293206524
# Image: ../data/original_data/images\vid_000532_frame0000201.jpg, Sharpness: 2837.201491194178
# Image: ../data/original_data/images\vid_000271_frame0000026.jpg, Sharpness: 791.3250771583503
# Sharpness results saved to sharpness_results.csv

# %%
# Sort the sample by their sharpness values.

sorted_sharpness_results = sorted(sharpness_results, key=lambda x: x[1])

# Select 5–10 images from the lowest and highest ranges of sharpness values.

num_images = 5
lowest_sharpness_images = sorted_sharpness_results[:num_images]
highest_sharpness_images = sorted_sharpness_results[-num_images:]

# Display the selected images

import matplotlib.pyplot as plt

def display_images(image_paths, title):
    fig, axes = plt.subplots(1, len(image_paths), figsize=(15, 15))
    fig.suptitle(title, fontsize=16)
    for i, (image_path, sharpness) in enumerate(image_paths):
        image = cv2.imread(image_path)
        axes[i].imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        axes[i].set_title(f"Sharpness: {sharpness:.2f}")
        axes[i].axis('off')
    plt.show()

display_images(lowest_sharpness_images, "Lowest Sharpness Images")
display_images(highest_sharpness_images, "Highest Sharpness Images")
